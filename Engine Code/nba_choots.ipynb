# %%
import pandas as pd

# %%
df1 = pd.read_csv('NB3.csv')

# %%
df2 = pd.read_csv('NB4.csv')

# %%
df3 = pd.read_csv('NB5.csv')

# %%
print(df1)
print(df2)
print(df3)
# Out:
#             0           1           2           3           4           5  \
# 0    J Harden    J Harden  A Igoudala    J Harden  A Igoudala    J Harden
# 1     S Curry     S Curry    J Harden     S Curry    J Harden     S Curry
# 2      Q Cook      Q Cook     S Curry      Q Cook     S Curry      Q Cook
# 3      C Paul  I Shempert      Q Cook    E Gordon      Q Cook    E Gordon
# 4  I Shempert    A Rivers    E Gordon  I Shempert    E Gordon  I Shempert
# 5    A Rivers  K Thompson     D Green    A Rivers  I Shempert     D Green
# 6     D Green     D Green    A Rivers     D Green     D Green    K Looney
# 7    K Looney    P Tucker    K Looney    P Tucker    K Looney    P Tucker
#
#             6           7           8           9          10          11  \
# 0    J Harden  A Igoudala  A Igoudala  A Igoudala    J Harden  A Igoudala
# 1     S Curry    J Harden    J Harden    J Harden     S Curry    J Harden
# 2      Q Cook     S Curry     S Curry     S Curry      Q Cook     S Curry
# ...

# %%
final = pd.concat([df1.T,df2.T,df3.T])
final = final.T
name = [i for i in range(1,50)]
final.columns = name
final
# Out:
#            1           2           3           4           5           6   \
# 0    J Harden    J Harden  A Igoudala    J Harden  A Igoudala    J Harden
# 1     S Curry     S Curry    J Harden     S Curry    J Harden     S Curry
# 2      Q Cook      Q Cook     S Curry      Q Cook     S Curry      Q Cook
# 3      C Paul  I Shempert      Q Cook    E Gordon      Q Cook    E Gordon
# 4  I Shempert    A Rivers    E Gordon  I Shempert    E Gordon  I Shempert
# 5    A Rivers  K Thompson     D Green    A Rivers  I Shempert     D Green
# 6     D Green     D Green    A Rivers     D Green     D Green    K Looney
# 7    K Looney    P Tucker    K Looney    P Tucker    K Looney    P Tucker
#
#            7           8           9           10     ...              40  \
# 0    J Harden  A Igoudala  A Igoudala  A Igoudala     ...      I Shempert
# 1     S Curry    J Harden    J Harden    J Harden     ...        K Durant
# 2      Q Cook     S Curry     S Curry     S Curry     ...        E Gordon
# ...

# %%
final = final.T

# %%
count=0
for i,r in final.iterrows():
    n = [r[0],r[1],r[2],r[3],r[4],r[5],r[6],r[7]]
    
    for j,c in final.iterrows():
        m = [c[0],c[1],c[2],c[3],c[4],c[5],c[6],c[7]]
        if n==m:
            count = count+1
            print(n)
print(count)
# Out:
# ['J Harden', 'S Curry', 'Q Cook', 'C Paul', 'I Shempert', 'A Rivers', 'D Green', 'K Looney']
# ['J Harden', 'S Curry', 'Q Cook', 'I Shempert', 'A Rivers', 'K Thompson', 'D Green', 'P Tucker']
# ['A Igoudala', 'J Harden', 'S Curry', 'Q Cook', 'E Gordon', 'D Green', 'A Rivers', 'K Looney']
# ['J Harden', 'S Curry', 'Q Cook', 'E Gordon', 'I Shempert', 'A Rivers', 'D Green', 'P Tucker']
# ['A Igoudala', 'J Harden', 'S Curry', 'Q Cook', 'E Gordon', 'I Shempert', 'D Green', 'K Looney']
# ['J Harden', 'S Curry', 'Q Cook', 'E Gordon', 'I Shempert', 'D Green', 'K Looney', 'P Tucker']
# ['J Harden', 'S Curry', 'Q Cook', 'E Gordon', 'I Shempert', 'D Green', 'K Looney', 'C Capela']
# ['A Igoudala', 'J Harden', 'S Curry', 'Q Cook', 'I Shempert', 'A Rivers', 'D Green', 'P Tucker']
# ['A Igoudala', 'J Harden', 'S Curry', 'Q Cook', 'D Green', 'A Rivers', 'K Looney', 'P Tucker']
# ['A Igoudala', 'J Harden', 'S Curry', 'Q Cook', 'D Green', 'A Rivers', 'K Looney', 'C Capela']
# ...

# %%
final = final.T
final
# Out:
#            1           2           3           4           5           6   \
# 0    J Harden    J Harden  A Igoudala    J Harden  A Igoudala    J Harden
# 1     S Curry     S Curry    J Harden     S Curry    J Harden     S Curry
# 2      Q Cook      Q Cook     S Curry      Q Cook     S Curry      Q Cook
# 3      C Paul  I Shempert      Q Cook    E Gordon      Q Cook    E Gordon
# 4  I Shempert    A Rivers    E Gordon  I Shempert    E Gordon  I Shempert
# 5    A Rivers  K Thompson     D Green    A Rivers  I Shempert     D Green
# 6     D Green     D Green    A Rivers     D Green     D Green    K Looney
# 7    K Looney    P Tucker    K Looney    P Tucker    K Looney    P Tucker
#
#            7           8           9           10     ...              40  \
# 0    J Harden  A Igoudala  A Igoudala  A Igoudala     ...      I Shempert
# 1     S Curry    J Harden    J Harden    J Harden     ...        K Durant
# 2      Q Cook     S Curry     S Curry     S Curry     ...        E Gordon
# ...

# %%
final.to_csv('gsw.csv')

# %%
count=0
for i,r in final.iterrows():
    n = [r[0],r[1],r[2],r[3],r[4],r[5],r[6],r[7]]
